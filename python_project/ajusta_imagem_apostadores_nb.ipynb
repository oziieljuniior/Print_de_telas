# %%
import os
import cv2
from pytesseract import pytesseract
from matplotlib import pyplot as plt
from openpyxl import Workbook
import numpy as np

# %%
name_path = "C:/Users/Riallen/Documents/Print_de_telas/data1/qt_apostadores/230T_Apostadores.png"
image = cv2.imread(name_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

kernel = np.ones((1,3),np.float32)/25
dst = cv2.filter2D(gray,-1,kernel)

#remove_noise = cv2.medianBlur(dst,1)
#blur =cv2.GaussianBlur(dst, (3,3), 1)
#thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

#kernel = np.ones((5,3),np.uint8)
#opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel)
#canny = cv2.Canny(opening, 100, 100)
    
plt.imshow(dst),plt.show()

#C:\Program Files\Tesseract-OCR\tesseract.exe
pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

custom_config = r'--oem 3 --psm 11 outputbase digits'
text = pytesseract.image_to_string(dst, config=custom_config)

print(text)
# Out:
# 1111

# %%
i = 0

while i<= 500:
    name = str(i) + 'T_Apostadores.png'
    print("Imagem: ", i)
    name_path = "C:/Users/Riallen/Documents/Print_de_telas/data1/qt_apostadores/"+name
    image = cv2.imread(name_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    kernel = np.ones((1,3),np.float32)/25
    dst = cv2.filter2D(gray,-1,kernel)

    blur = cv2.GaussianBlur(dst, (1,1), 0)
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    

    plt.imshow(thresh),plt.show()

    i += 1
